# %% [markdown]
# <h1>posttest 4</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#Data Split
from sklearn.model_selection import train_test_split
#Data Transforming
from sklearn.preprocessing import StandardScaler #standarisasi
from sklearn.preprocessing import MinMaxScaler #normalisasi
#Data Cleaning
from sklearn.impute import SimpleImputer
#Data Encoding
from sklearn.preprocessing import OrdinalEncoder #encoder
from sklearn.preprocessing import OneHotEncoder #onehot

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df2 = pd.read_csv("league-of-spuds.csv")

# %%
df2
# Out:
#       accountId  name summonerName  participantId    win  item0  item1  item2  \
# 0     200394182    MJ  TheRoughead              7   True   3004   1055   3057
# 1     200394182    MJ  TheRoughead              7  False   2420   1400   3134
# 2     200394182    MJ  TheRoughead              4  False   3071   1400   3134
# 3     200394182    MJ  TheRoughead              2  False   3083   1400   3134
# 4     200394182    MJ  TheRoughead              7   True   3078   1055   3004
# ...         ...   ...          ...            ...    ...    ...    ...    ...
# 6293  200053490  Lach      patto33              4  False   3153   3087   1304
# 6294  200053490  Lach      patto33              5   True   3144   3110   3065
# 6295  200053490  Lach      patto33              3   True   3430   1056   3196
# 6296  200053490  Lach      patto33              9   True   1056   3027   3434
# 6297  200053490  Lach      patto33             10  False   3401   2049   1340
#
# ...

# %%
df2.isna().sum()
# Out:
# accountId              0
# name                   0
# summonerName           0
# participantId          0
# win                    0
#                     ...
# perk5Var2           5456
# perk5Var3           5456
# perkPrimaryStyle    5456
# perkSubStyle        5456
# gameId                 0
# Length: 105, dtype: int64

# %%
df3 = pd.read_csv("Anime_data.csv")

# %%
df3
# Out:
#        Anime_id                                            Title  \
# 0             1                                     Cowboy Bebop
# 1             5                  Cowboy Bebop: Tengoku no Tobira
# 2             6                                           Trigun
# 3             7                               Witch Hunter Robin
# 4             8                                   Bouken Ou Beet
# ...         ...                                              ...
# 16997     27499  Sore Ike! Anpanman: Anpanman to Kaizoku Lobster
# 16998     12091                                         X Bomber
# 16999     29133                                   X Bomber Pilot
# 17000     34485                                       Ganko-chan
# 17001     32713                            Original C-V-P Momoko
#
#                                                    Genre  \
# 0      ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1      ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# ...

# %% [markdown]
# #Data split

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,:-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.3)

# %%
print(f"Panjang X_train : {len(x_train)}",
      f"Panjang X_test : {len(x_test)}",
      f"Panjang y_train : {len(y_train)}",
      f"Panjang y_test : {len(y_test)}",
      sep='\n')
# Out:
# Panjang X_train : 6164
# Panjang X_test : 2643
# Panjang y_train : 6164
# Panjang y_test : 2643

# %% [markdown]
# #Data transforming

# %%
normalisasi_dataset = df2.copy()

# %%
scaler = MinMaxScaler()

normalize_dataset = scaler.fit_transform(normalisasi_dataset[['item0', 'item1', 'item2']])

normalize_dataset = pd.DataFrame(normalize_dataset)
normalize_dataset.rename(columns={0 :'item0', 1 :'item1', 2 : 'item2'}, inplace=True)

normalize_dataset.head(5)
# Out:
#       item0     item1     item2
# 0  0.763794  0.268448  0.762344
# 1  0.615306  0.356234  0.781546
# 2  0.780829  0.356234  0.781546
# 3  0.783880  0.356234  0.781546
# 4  0.782609  0.268448  0.749127

# %% [markdown]
# #Data cleaning

# %%
dataset_cl1 = df2.copy()
dataset_cl2 = df2.copy()
dataset_cl3 = df2.copy()

# %%
imputer_mean = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
imputer_modus = SimpleImputer(strategy='most_frequent')

# %% [markdown]
# #Modus

# %%
dataset_cl1['perkSubStyle'] = imputer_modus.fit_transform(dataset_cl1[['perkSubStyle']])

dataset_cl1.isna().sum()
# Out:
# accountId              0
# name                   0
# summonerName           0
# participantId          0
# win                    0
#                     ...
# perk5Var2           5456
# perk5Var3           5456
# perkPrimaryStyle    5456
# perkSubStyle           0
# gameId                 0
# Length: 105, dtype: int64

# %% [markdown]
# #Mean

# %%
dataset_cl2['perk5Var3'] = imputer_mean.fit_transform(dataset_cl2[['perk5Var3']])

dataset_cl2.isna().sum()
# Out:
# accountId              0
# name                   0
# summonerName           0
# participantId          0
# win                    0
#                     ...
# perk5Var2           5456
# perk5Var3              0
# perkPrimaryStyle    5456
# perkSubStyle        5456
# gameId                 0
# Length: 105, dtype: int64

# %% [markdown]
# #Menghapus Record

# %%
dataset_cl3.dropna(inplace=True)

dataset_cl3.isna().sum()
# Out:
# accountId           0
# name                0
# summonerName        0
# participantId       0
# win                 0
#                    ..
# perk5Var2           0
# perk5Var3           0
# perkPrimaryStyle    0
# perkSubStyle        0
# gameId              0
# Length: 105, dtype: int64

# %%
dataset_duplicate = df3.copy()

dataset_duplicate.duplicated().sum()
# Out:
# 63

# %%
dataset_duplicate.drop_duplicates(inplace=True)

dataset_duplicate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #standarisasi

# %%
standarisasi_dataset = dataset_cl3

# %%
ss = StandardScaler()
Scaled_data = ss.fit_transform(standarisasi_dataset[['item0', 'item1', 'item3']])

# %%
print("Nilai Sebelum Standarisasi : ")
print("Standar Deviasi : ", np.std(standarisasi_dataset))
# Out:
# Nilai Sebelum Standarisasi :
# Standar Deviasi :  accountId           6.634388e+05
# participantId       2.857407e+00
# win                 4.982126e-01
# item0               9.727245e+02
# item1               7.152785e+02
#                         ...
# perk5Var2           5.938840e+01
# perk5Var3           1.684151e+00
# perkPrimaryStyle    1.377055e+02
# perkSubStyle        1.194295e+02
# gameId              7.554106e+06
# Length: 103, dtype: float64
# C:\Users\hpsam\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3571: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %% [markdown]
# #Data encoding

# %%
dataset_ordinal = df3.copy()
dataset_one_hot = df3.copy()

# %% [markdown]
# #ordinal encoding

# %%
df3['Type'].unique()
# Out:
# array(['TV', 'Movie', 'OVA', 'Special', 'ONA', 'Music', 'Unknown', nan],
#       dtype=object)

# %%
encoder_ordinal =OrdinalEncoder()

#encoding kan
dataset_ordinal['Type'] = encoder_ordinal.fit_transform(dataset_ordinal[['Type']]).astype('int64')

#lihat
dataset_ordinal.head()
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis  Type  \
# 0  In the year 2071, humanity has colonized sever...     5
# 1  Another day, another bounty—such is the life o...     0
# 2  Vash the Stampede is the man with a $$60,000,0...     5
# 3  Witches are individuals with special powers li...     5
# 4  It is the dark century and the people are suff...     5
#
# ...

# %%
dataset_ordinal['Type'].unique()
# Out:
# array([                   5,                    0,                    3,
#                           4,                    2,                    1,
#                           6, -9223372036854775808], dtype=int64)

# %% [markdown]
# #One-hot-encoding

# %%
temp_dataset = pd.get_dummies(dataset_one_hot[['Type']])

temp_dataset = pd.DataFrame(temp_dataset)

dataset_one_hot.drop('Type', axis=1, inplace=True)

dataset_one_hot = dataset_one_hot.join(temp_dataset)
dataset_one_hot.head(5)
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Witches are individuals with special powers li...
# 4  It is the dark century and the people are suff...
#
# ...
